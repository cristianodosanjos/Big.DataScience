# %% [markdown]
# # Our objective in this project is find out the worse and best instrument of investment in 2010 to 2016 and  make a great graphic that show it for us.

# %% [markdown]
# ...

# %% [markdown]
# Importing libraries that will help us.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %% [markdown]
# And now we can pick up the data and print some observations.

# %%
db = pd.read_csv("C:/Users/GEANUM.Fé/Documents/Project-A/prices-split-adjusted.csv")
db = pd.DataFrame(db)
db.head()
# Out:
#          date symbol        open       close         low        high  \
# 0  2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
db.tail(3)
# Out:
#               date symbol       open      close        low       high  \
# 851261  2016-12-30    ZTS  53.639999  53.529999  53.270000  53.740002
# 851262  2016-12-30    AIV  44.730000  45.450001  44.410000  45.590000
# 851263  2016-12-30    FTV  54.200001  53.630001  53.389999  54.480000
#
#            volume
# 851261  1701200.0
# 851262  1380900.0
# 851263   705100.0

# %% [markdown]
# ...

# %% [markdown]
# PART 1 : Now let's see which instrument of investment was the worse for ours investors that stayed still the final of 2016.

# %% [markdown]
# ...

# %%
db.corr()
# Out:
#             open     close       low      high    volume
# open    1.000000  0.999845  0.999914  0.999928 -0.132526
# close   0.999845  1.000000  0.999926  0.999925 -0.132675
# low     0.999914  0.999926  1.000000  0.999889 -0.133087
# high    0.999928  0.999925  0.999889  1.000000 -0.132168
# volume -0.132526 -0.132675 -0.133087 -0.132168  1.000000

# %%
db.columns = ['date', 'instrument', 'open', 'close', 'low', 'high', 'volume']
db.head()
# Out:
#          date instrument        open       close         low        high  \
# 0  2016-01-05       WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06       WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07       WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08       WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11       WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume
# 0  2163600.0
# 1  2386400.0
# 2  2489500.0
# 3  2006300.0
# 4  1408600.0

# %%
print('The operaions in this data began on:','',db['date'].min(), 'and ended in:','',db['date'].max())
# Out:
# The operaions in this data began on:  2010-01-04 and ended in:  2016-12-30

# %%
db['difference'] = db['close'] - db['open']
db.head()
# Out:
#          date instrument        open       close         low        high  \
# 0  2016-01-05       WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06       WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07       WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08       WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11       WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume  difference
# 0  2163600.0    2.409996
# 1  2386400.0   -5.259995
# 2  2489500.0   -1.430000
# 3  2006300.0    1.140000
# 4  1408600.0   -2.040001

# %%
db['downfall'] = db['close'] - db['high']
db.head()
# Out:
#          date instrument        open       close         low        high  \
# 0  2016-01-05       WLTW  123.430000  125.839996  122.309998  126.250000
# 1  2016-01-06       WLTW  125.239998  119.980003  119.940002  125.540001
# 2  2016-01-07       WLTW  116.379997  114.949997  114.930000  119.739998
# 3  2016-01-08       WLTW  115.480003  116.620003  113.500000  117.440002
# 4  2016-01-11       WLTW  117.010002  114.970001  114.089996  117.330002
#
#       volume  difference  downfall
# 0  2163600.0    2.409996 -0.410004
# 1  2386400.0   -5.259995 -5.559998
# 2  2489500.0   -1.430000 -4.790001
# 3  2006300.0    1.140000 -0.819999
# 4  1408600.0   -2.040001 -2.360001

# %% [markdown]
# The column difference show us the profit and loss in each time with every instrument, the column downfall is the drop in money.

# %%
db.tail()
# Out:
#               date instrument        open       close         low        high  \
# 851259  2016-12-30        ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30       ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30        ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30        AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30        FTV   54.200001   53.630001   53.389999   54.480000
#
#            volume  difference  downfall
# 851259   973800.0   -0.110001 -0.730003
# 851260  1938100.0   -0.029999 -0.270000
# 851261  1701200.0   -0.110000 -0.210003
# 851262  1380900.0    0.720001 -0.139999
# 851263   705100.0   -0.570000 -0.849999

# %%
dtt = db.groupby('instrument')['difference'].sum()
print(dtt.head(), dtt.tail())
# Out:
# instrument
# A       26.308161
# AAL     -2.360043
# AAP     79.389958
# AAPL   -44.158706
# ABBV    32.820069
# Name: difference, dtype: float64 instrument
# YHOO   -10.440023
# YUM     40.182147
# ZBH     84.649941
# ZION    19.619932
# ZTS     -7.560046
# Name: difference, dtype: float64

# %%
print('max is:', dtt.max(), '  and min is :', dtt.min())
# Out:
# max is: 329.3397310000014   and min is : -365.82931747799927

# %%
dtt = pd.DataFrame(dtt)
dt = dtt.reset_index(drop = False)

# %%
dt.head()
# Out:
#   instrument  difference
# 0          A   26.308161
# 1        AAL   -2.360043
# 2        AAP   79.389958
# 3       AAPL  -44.158706
# 4       ABBV   32.820069

# %%
dt.query('difference > 300')
# Out:
#     instrument  difference
# 245       ISRG  329.339731

# %%
dt.query('difference < -300')
# Out:
#     instrument  difference
# 201       GOOG -333.231906
# 202      GOOGL -365.829317

# %% [markdown]
# We found out the instrument responsible for more loss is the GOOGL with -365.829317 and the instrument with more profit was ISRG with 329.339731 of earnings.

# %% [markdown]
# ...

# %% [markdown]
# PART 2 :  Now we need to know why the GOOGL was worse than ISRG, let's see the moments when the best and worst instrument was with high and low income according to the following graphics.

# %% [markdown]
# ...

# %%
db.tail()
# Out:
#               date instrument        open       close         low        high  \
# 851259  2016-12-30        ZBH  103.309998  103.199997  102.849998  103.930000
# 851260  2016-12-30       ZION   43.070000   43.040001   42.689999   43.310001
# 851261  2016-12-30        ZTS   53.639999   53.529999   53.270000   53.740002
# 851262  2016-12-30        AIV   44.730000   45.450001   44.410000   45.590000
# 851263  2016-12-30        FTV   54.200001   53.630001   53.389999   54.480000
#
#            volume  difference  downfall
# 851259   973800.0   -0.110001 -0.730003
# 851260  1938100.0   -0.029999 -0.270000
# 851261  1701200.0   -0.110000 -0.210003
# 851262  1380900.0    0.720001 -0.139999
# 851263   705100.0   -0.570000 -0.849999

# %%
dt2 = pd.DataFrame(db.sort_values(by='date'))

# %%
dt2.head()
# Out:
#            date instrument       open      close    low       high  \
# 646  2010-01-04       SYMC  18.040001  18.400000  18.01  18.530001
# 473  2010-01-04        IFF  41.509998  42.009998  41.50  42.020000
# 474  2010-01-04       ILMN  31.120001  30.549999  30.42  31.230000
# 475  2010-01-04       INTC  20.790001  20.879999  20.73  21.030001
# 476  2010-01-04       INTU  31.090000  30.809999  30.77  31.150000
#
#          volume  difference  downfall
# 646   8322300.0    0.359999 -0.130001
# 473    286000.0    0.500000 -0.010002
# 474   1793700.0   -0.570002 -0.680001
# 475  47800900.0    0.089998 -0.150002
# 476   2353000.0   -0.280001 -0.340001

# %%
dt2.tail()
# Out:
#               date instrument       open      close        low       high  \
# 850922  2016-12-30         ES  55.599998  55.230000  55.070000  55.740002
# 850921  2016-12-30        EQT  65.699997  65.400002  65.050003  66.470001
# 850920  2016-12-30        EQR  63.590000  64.360001  63.189999  64.440002
# 850933  2016-12-30        EXR  75.669998  77.239998  75.110001  77.300003
# 851263  2016-12-30        FTV  54.200001  53.630001  53.389999  54.480000
#
#            volume  difference  downfall
# 850922  1446800.0   -0.369998 -0.510002
# 850921  1242100.0   -0.299995 -1.069999
# 850920  1534000.0    0.770001 -0.080001
# 850933   884400.0    1.570000 -0.060005
# 851263   705100.0   -0.570000 -0.849999

# %%
dt3 = dt2
dt3.index = dt3['date']

# %%
dt3 = dt3[['instrument', 'open', 'close', 'low', 'high', 'volume', 'difference', 'downfall']]
dt3.head()
# Out:
#            instrument       open      close    low       high      volume  \
# date
# 2010-01-04       SYMC  18.040001  18.400000  18.01  18.530001   8322300.0
# 2010-01-04        IFF  41.509998  42.009998  41.50  42.020000    286000.0
# 2010-01-04       ILMN  31.120001  30.549999  30.42  31.230000   1793700.0
# 2010-01-04       INTC  20.790001  20.879999  20.73  21.030001  47800900.0
# 2010-01-04       INTU  31.090000  30.809999  30.77  31.150000   2353000.0
#
#             difference  downfall
# date
# 2010-01-04    0.359999 -0.130001
# 2010-01-04    0.500000 -0.010002
# 2010-01-04   -0.570002 -0.680001
# 2010-01-04    0.089998 -0.150002
# 2010-01-04   -0.280001 -0.340001

# %%
d3 = dt3[dt3['instrument']=='ISRG']
d3.head()
# Out:
#            instrument        open       close         low        high  \
# date
# 2010-01-04       ISRG  307.200012  308.769989  305.799988  309.089996
# 2010-01-05       ISRG  308.010010  307.380005  304.000000  309.920013
# 2010-01-06       ISRG  305.450012  311.839996  305.450012  312.790009
# 2010-01-07       ISRG  310.720001  310.670013  309.420013  314.000000
# 2010-01-08       ISRG  310.670013  308.959991  308.489990  312.700012
#
#               volume  difference  downfall
# date
# 2010-01-04  337100.0    1.569977 -0.320007
# 2010-01-05  410100.0   -0.630005 -2.540008
# 2010-01-06  555100.0    6.389984 -0.950013
# 2010-01-07  294600.0   -0.049988 -3.329987
# 2010-01-08  295300.0   -1.710022 -3.740021

# %%
d3.tail()
# Out:
#            instrument        open       close         low        high  \
# date
# 2016-12-23       ISRG  639.080017  640.750000  638.320007  644.679993
# 2016-12-27       ISRG  643.039978  639.510010  639.270020  647.200012
# 2016-12-28       ISRG  639.799988  635.549988  633.729980  642.409973
# 2016-12-29       ISRG  634.570007  636.549988  634.570007  639.000000
# 2016-12-30       ISRG  638.320007  634.169983  632.250000  638.390015
#
#               volume  difference  downfall
# date
# 2016-12-23  188800.0    1.669983 -3.929993
# 2016-12-27  119400.0   -3.529968 -7.690002
# 2016-12-28  159700.0   -4.250000 -6.859985
# 2016-12-29  157600.0    1.979981 -2.450012
# 2016-12-30  267300.0   -4.150024 -4.220032

# %%
d3.corr()
# Out:
#                 open     close       low      high    volume  difference  \
# open        1.000000  0.998099  0.999006  0.999174 -0.248956   -0.035451
# close       0.998099  1.000000  0.999220  0.999128 -0.249527    0.026201
# low         0.999006  0.999220  1.000000  0.998899 -0.262657   -0.001151
# high        0.999174  0.999128  0.998899  1.000000 -0.236564   -0.005373
# volume     -0.248956 -0.249527 -0.262657 -0.236564  1.000000   -0.008108
# difference -0.035451  0.026201 -0.001151 -0.005373 -0.008108    1.000000
# downfall   -0.098321 -0.051888 -0.065000 -0.093531 -0.291951    0.753462
#
#             downfall
# open       -0.098321
# close      -0.051888
# low        -0.065000
# high       -0.093531
# volume     -0.291951
# difference  0.753462
# downfall    1.000000

# %%
d33 = d3
d33['date'] = d3.index
d33.head()
# Out:
# C:\Users\GEANUM.Fé\Documents\WPy64-3760\python-3.7.6.amd64\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#            instrument        open       close         low        high  \
# date
# 2010-01-04       ISRG  307.200012  308.769989  305.799988  309.089996
# 2010-01-05       ISRG  308.010010  307.380005  304.000000  309.920013
# 2010-01-06       ISRG  305.450012  311.839996  305.450012  312.790009
# 2010-01-07       ISRG  310.720001  310.670013  309.420013  314.000000
# 2010-01-08       ISRG  310.670013  308.959991  308.489990  312.700012
#
#               volume  difference  downfall        date
# date
# 2010-01-04  337100.0    1.569977 -0.320007  2010-01-04
# ...

# %%
d32 = d33[['difference','date']].iloc[:30]
d32 = pd.DataFrame(d32)
d32.head()
# Out:
#             difference        date
# date
# 2010-01-04    1.569977  2010-01-04
# 2010-01-05   -0.630005  2010-01-05
# 2010-01-06    6.389984  2010-01-06
# 2010-01-07   -0.049988  2010-01-07
# 2010-01-08   -1.710022  2010-01-08

# %%
d32.index.name = None
d32.tail()
# Out:
#             difference        date
# 2010-02-09   -1.160004  2010-02-09
# 2010-02-10   -4.889984  2010-02-10
# 2010-02-11    8.979980  2010-02-11
# 2010-02-12    5.809997  2010-02-12
# 2010-02-16    0.819977  2010-02-16

# %%
d2 = d3[['difference','date']]
d2.index.name = None
d2.tail()
# Out:
#             difference        date
# 2016-12-23    1.669983  2016-12-23
# 2016-12-27   -3.529968  2016-12-27
# 2016-12-28   -4.250000  2016-12-28
# 2016-12-29    1.979981  2016-12-29
# 2016-12-30   -4.150024  2016-12-30

# %%
m_oney = d2.iloc[:252]
m_twoy = d2.iloc[253:504]
m = d2.iloc[:504]
m.tail()
# Out:
#             difference        date
# 2011-12-23    7.660004  2011-12-23
# 2011-12-27    4.970001  2011-12-27
# 2011-12-28   -7.289978  2011-12-28
# 2011-12-29    8.399994  2011-12-29
# 2011-12-30   -3.309997  2011-12-30

# %%
dt22 = dt2[dt2['instrument']=='GOOGL']
dt22.head()
# Out:
#                   date instrument        open       close         low  \
# date
# 2010-01-04  2010-01-04      GOOGL  313.788792  313.688694  312.432438
# 2010-01-05  2010-01-05      GOOGL  313.903904  312.307316  311.081089
# 2010-01-06  2010-01-06      GOOGL  313.243260  304.434452  303.483494
# 2010-01-07  2010-01-07      GOOGL  305.005009  297.347355  296.621617
# 2010-01-08  2010-01-08      GOOGL  296.296299  301.311314  294.849857
#
#                   high      volume  difference  downfall
# date
# 2010-01-04  315.070073   3908400.0   -0.100098 -1.381378
# 2010-01-05  314.234226   6003300.0   -1.596589 -1.926910
# 2010-01-06  313.243260   7949400.0   -8.808808 -8.808808
# 2010-01-07  305.305302  12815700.0   -7.657654 -7.957947
# 2010-01-08  301.926945   9439100.0    5.015015 -0.615631

# %%
dt22['date'] = dt22.index
dt222 = dt22[['difference','date']]
dt222.index.name = None
n = dt222.iloc[:504]
n.tail()
# Out:
# C:\Users\GEANUM.Fé\Documents\WPy64-3760\python-3.7.6.amd64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             difference        date
# 2011-12-23    0.570587  2011-12-23
# 2011-12-27    4.104096  2011-12-27
# 2011-12-28   -1.526520  2011-12-28
# 2011-12-29    0.455444  2011-12-29
# 2011-12-30    1.941956  2011-12-30

# %% [markdown]
# In the line above we pick up 2 first years of the best and the worse instrument to make a graphic that will show us about the earnings and loss in the months of 2010 and 2011.

# %%
with  plt.style.context('dark_background'):
    n.plot(kind='area',alpha=0.35,stacked=False,figsize=(16,6))
    plt.axhline(0,color='red')
    plt.xlabel('2010 to final of 2011')
    plt.ylabel('Earnings and loss of GOOGL')
    plt.show()

# %%
with plt.style.context('dark_background'):
    m.plot(kind='area',alpha=0.35,stacked=False,figsize=(16,6))
    plt.axhline(0,color='red')
    plt.xlabel('2010 to final of 2011')
    plt.ylabel('Earnings and loss of ISRG')
    plt.show()

# %% [markdown]
# We can see above the graphics about 2010 to final of 2011, now we will see graphics of the better and the worse intrument about performance of them between 2015 and 2017.

# %%
nf = dt222.iloc[1258:1762]

# %%
mf = d2.iloc[1258:1762]

# %%
with plt.style.context('dark_background'):
    nf.plot(kind='area',alpha=0.35,stacked=False,figsize=(16,6))
    plt.axhline(0,color='red')
    plt.xlabel('2015 to final of 2016')
    plt.ylabel('Earnings and loss of GOOGL')
    plt.show()

# %%
with plt.style.context('dark_background'):
    mf.plot(kind='area',alpha=0.35,stacked=False,figsize=(16,6))
    plt.axhline(0,color='red')
    plt.xlabel('2015 to final of 2016')
    plt.ylabel('Earnings and loss of ISRG')
    plt.show()

# %% [markdown]
# It made me curious! In these graphics the difference between the major and  worse instrument is unreadble with the column difference, maybe if we catch the median of them...

# %%
db2 = db.sort_values(by='date')
db2.head(2)
# Out:
#            date instrument       open      close    low       high     volume  \
# 646  2010-01-04       SYMC  18.040001  18.400000  18.01  18.530001  8322300.0
# 473  2010-01-04        IFF  41.509998  42.009998  41.50  42.020000   286000.0
#
#      difference  downfall
# 646    0.359999 -0.130001
# 473    0.500000 -0.010002

# %%
db2m = db2[db2['instrument']=='ISRG']
db2n = db2[db2['instrument']=='GOOGL']
db2n.tail(2)
# Out:
#               date instrument        open       close         low        high  \
# 850464  2016-12-29      GOOGL  802.330017  802.880005  798.140015  805.750000
# 850964  2016-12-30      GOOGL  803.210022  792.450012  789.619995  803.289978
#
#            volume  difference   downfall
# 850464  1056500.0    0.549988  -2.869995
# 850964  1728300.0  -10.760010 -10.839966

# %%
db2n.mean()
# Out:
# open          4.672966e+02
# close         4.670890e+02
# low           4.630376e+02
# high          4.710429e+02
# volume        4.096043e+06
# difference   -2.076216e-01
# downfall     -3.953944e+00
# dtype: float64

# %%
db2m.mean()
# Out:
# open             461.787991
# close            461.974904
# low              456.810670
# high             466.889830
# volume        419465.039728
# difference         0.186912
# downfall          -4.914926
# dtype: float64

# %% [markdown]
# As we can see the average earnings of the instrument ISRG in 6 years is: 0.186812 and the average of GOOGL is: -2.076216.

# %%
dm1 = db2m['difference'].iloc[:252].mean()
dm2 = db2m['difference'].iloc[252:504].mean()
dm3 = db2m['difference'].iloc[504:754].mean()
dm4 = db2m['difference'].iloc[754:1006].mean()
dm5 = db2m['difference'].iloc[1006:1217].mean()
dm6 = db2m['difference'].iloc[1217:1529].mean()
dm7 = db2m['difference'].iloc[1529:].mean()

# %%
dn1 = db2n['difference'].iloc[:252].mean()
dn2 = db2n['difference'].iloc[252:504].mean()
dn3 = db2n['difference'].iloc[504:754].mean()
dn4 = db2n['difference'].iloc[754:1006].mean()
dn5 = db2n['difference'].iloc[1006:1217].mean()
dn6 = db2n['difference'].iloc[1217:1529].mean()
dn7 = db2n['difference'].iloc[1529:].mean()

# %%
nnn = pd.DataFrame([dn1,dn2,dn3,dn4,dn5,dn6,dn7]).transpose()
nnn.head(2)
# Out:
#           0         1         2         3         4         5         6
# 0 -0.344789 -0.098866  0.013014  0.311581 -0.796302 -0.251604 -0.383176

# %%
nnn = nnn.transpose()

# %%
nnn.index = ['2010','2011','2012','2013','2014','2015','2016']
nnn.columns = ['difference']
nnn.head(2)
# Out:
#       difference
# 2010   -0.344789
# 2011   -0.098866

# %%
mmm = pd.DataFrame([dm1,dm2,dm3,dm4,dm5,dm6,dm7]).transpose()
mmm.head(2)
# Out:
#          0        1      2         3         4         5         6
# 0 -0.22131  0.72496  0.348 -0.190358  0.075829  0.199552  0.365365

# %%
mmm = mmm.transpose()

# %%
mmm.index = ['2010','2011','2012','2013','2014','2015','2016']
mmm.columns = ['difference']
mmm.head(2)
# Out:
#       difference
# 2010    -0.22131
# 2011     0.72496

# %% [markdown]
# Now let's make the graphics.

# %%
with plt.style.context('dark_background'):
    mmm.plot(kind='area',alpha=0.35,stacked=False,figsize=(16,6))
    plt.axhline(0,color='red')
    plt.xlabel(' Years')
    plt.ylabel('Average values of ISRG')
    plt.show()

# %%
with plt.style.context('dark_background'):
    nnn.plot(kind='area',alpha=0.35,stacked=False,figsize=(16,6))
    plt.axhline(0,color='red')
    plt.xlabel('Years')
    plt.ylabel('Average values of GOOGL')
    plt.show()

# %% [markdown]
# As we can see analyzing the graphics above, the average values of ISRG in each year was better than GOOGL.

# %% [markdown]
# ...

# %% [markdown]
# ...

# %% [markdown]
# # Thank you for analyze with me.
